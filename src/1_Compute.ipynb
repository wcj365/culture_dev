# %% [markdown]
# # Exploring the Association between Culture and Development
#
# Hoffstede defined natural culture as the collective programing of people which affect how they think, behavor, and act as a group. The development of a nation include their health status, economic output, energy consumption, and many other aspects. It is only natural to think culture and development are related as how we think and act may affect how we produce and consume. Wise verse, how we produce and consume may affect how we think and act.
#
# This exploratory study will use world development indicators data from the World Bank and national cultural dimensions data from the Hoffstede to find out if the association exists and the nature of the association.

# %% [markdown]
# ## Part 1 - Compute Statistics

# %% [markdown]
# ### Step 1 - Import Python libraries

# %%
import pandas as pd
import plotly.express as px
import statsmodels.api as sm
from scipy.stats import pearsonr

# %% [markdown]
# ## Step 2 - Load and Merge Datasets

# %%
# The national culture dimension dataset was download from Hoffstede and preprocessed and uploaded to the GitHub

CULTURE_DATA_URL = "https://raw.githubusercontent.com/wcj365/public_data/master/national_culture_dimensions.csv"

df_cult = pd.read_csv(CULTURE_DATA_URL)

df_cult.head()
# Out:
#   Country Code Country Name  PDI  IDV  MAS  UAI  LTO  IVR
# 0          ARG    Argentina   49   46   56   86   20   62
# 1          AUS    Australia   38   90   61   51   21   71
# 2          AUT      Austria   11   55   79   70   60   63
# 3          BEL      Belgium   65   75   54   94   82   57
# 4          BGD   Bangladesh   80   20   55   60   47   20

# %%
df_cult.columns
# Out:
# Index(['Country Code', 'Country Name', 'PDI', 'IDV', 'MAS', 'UAI', 'LTO',
#        'IVR'],
#       dtype='object')

# %%
# The world development indicators dataset was downloaded from the World Bank website.
# The dataset is over 150 MB in size and exceed the limit of GitHub. 
# It is uploaded to the Google Drive.

WDI_DATA_URL = "https://drive.google.com/file/d/15uXGxk5aedtuss3yd3OsY2WU6UcJ1Vta/view?usp=sharing"

df_wdi = pd.read_csv("../data/WDIData.csv")

print(df_wdi.shape)

df_wdi.head()
# Out:
# (383572, 66)
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
# 3  Africa Eastern and Southern          AFE
# 4  Africa Eastern and Southern          AFE
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS   NaN
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2012       2013       2014  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  16.433999  16.789043  17.196986
# 1   NaN   NaN   NaN   NaN   NaN  ...   6.196543   6.397917   6.580066
# 2   NaN   NaN   NaN   NaN   NaN  ...  37.434876  37.660864  37.857526
# 3   NaN   NaN   NaN   NaN   NaN  ...  31.682318  31.610692  31.824950
# 4   NaN   NaN   NaN   NaN   NaN  ...  19.307850  18.535523  17.485006
#
#         2015       2016       2017       2018       2019       2020  2021
# 0  17.597176  18.034249  18.345878  18.695306  19.149942  19.501837   NaN
# 1   6.786218   6.941323   7.096843   7.254828   7.460783   7.599289   NaN
# 2  38.204173  38.303515  38.421813  38.482409  38.692053  38.793983   NaN
# 3  33.744405  38.733352  40.092163  42.880977  44.073912  45.609604   NaN
# 4  16.329765  24.372504  25.153292  27.227391  29.383000  30.163364   NaN
#
# [5 rows x 66 columns]

# %%
# Merge the two datasets 

df_wdi.drop(columns=["Country Name", "Indicator Name"], inplace=True)
df_cult.drop(columns=["Country Name"], inplace=True)

df_merge = pd.merge(df_wdi, df_cult, how="inner", on="Country Code")

print(df_merge.shape)
df_merge.head()
# Out:
# (86520, 70)
#   Country Code     Indicator Code  1960  1961  1962  1963  1964  1965  1966  \
# 0          ARG     EG.CFT.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1          ARG  EG.CFT.ACCS.RU.ZS   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2          ARG  EG.CFT.ACCS.UR.ZS   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3          ARG     EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4          ARG  EG.ELC.ACCS.RU.ZS   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1967  ...       2018   2019   2020  2021  PDI  IDV  MAS  UAI  LTO  IVR
# 0   NaN  ...  99.800000   99.9   99.9   NaN   49   46   56   86   20   62
# 1   NaN  ...  96.600000   97.0   97.2   NaN   49   46   56   86   20   62
# 2   NaN  ...  99.900000   99.9   99.9   NaN   49   46   56   86   20   62
# 3   NaN  ...  99.989578  100.0  100.0   NaN   49   46   56   86   20   62
# 4   NaN  ...  99.871811  100.0  100.0   NaN   49   46   56   86   20   62
#
# [5 rows x 70 columns]

# %%
df_merge["Country Code"].nunique()
# Out:
# 60

# %%
df_merge["Indicator Code"].nunique()
# Out:
# 1442

# %% [markdown]
# ### Step 3 - Compute and Save the Correlation Statistics
#
# For every each and every indicator, compute:
#
# - Pearson's Correlation Coefficent and its P-value
# - OLS coefficient and its P-value
# - Coefficient of Determination (R Squared)
# - Adjusted Coefficient of Determination (R Squared Adjusted)
#
# These statistics are saved to a file in CSV format for future exploration.

# %% [markdown]
# #### 3.1 Compute Statistics

# %%
indicator_list = df_merge["Indicator Code"].unique()
year_list = [str(year) for year in range(1960, 2022)]

result_list = []


for year in year_list:

    for indicator in indicator_list:

        _df = df_merge[df_merge["Indicator Code"] == indicator][[year, "IDV"]].dropna()


        if _df.shape[0] <= 2:  # Must have at least three data points
            row = [year, indicator, _df.shape[0], None, None, None, None, None, None]
            result_list.append(row)
            continue
        else:
            X = _df["IDV"]
            Y = _df[year]
            pearson = pearsonr(X, Y)
            X = sm.add_constant(X) # adding a constant
            model = sm.OLS(Y, X).fit()
            row = [year, 
                   indicator, 
                   _df.shape[0], 
                   round(pearson[0],2), 
                   round(pearson[1],2), 
                   round(model.params[1],2), 
                   round(model.pvalues[1],2), 
                   round(model.rsquared,2), 
                   round(model.rsquared_adj,2)
            ]
 
        result_list.append(row)
# Out:
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /home/codespace/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /home/codespace/.python/current/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1752: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss

# %% [markdown]
# #### 3.2 Save the Statistics to a Dataframe

# %%
column_list = [
    "Year", 
    "Indicator Code", 
    "Countries", 
    "Pearson R",
    "Pearson P-value",
    "Coefficient",
    "P_value", 
    "R_Squared", 
    "R_Squared_Adj"
]

df_results = pd.DataFrame(result_list, columns=column_list)

print(df_results.shape)
df_results.head()
# Out:
# (89404, 9)
#    Year     Indicator Code  Countries  Pearson R  Pearson P-value  \
# 0  1960     EG.CFT.ACCS.ZS          0        NaN              NaN
# 1  1960  EG.CFT.ACCS.RU.ZS          0        NaN              NaN
# 2  1960  EG.CFT.ACCS.UR.ZS          0        NaN              NaN
# 3  1960     EG.ELC.ACCS.ZS          0        NaN              NaN
# 4  1960  EG.ELC.ACCS.RU.ZS          0        NaN              NaN
#
#    Coefficient  P_value  R_Squared  R_Squared_Adj
# 0          NaN      NaN        NaN            NaN
# 1          NaN      NaN        NaN            NaN
# 2          NaN      NaN        NaN            NaN
# 3          NaN      NaN        NaN            NaN
# 4          NaN      NaN        NaN            NaN

# %%
df_results.sample(10)
# Out:
#        Year           Indicator Code  Countries  Pearson R  Pearson P-value  \
# 19118  1973  SL.EMP.TOTL.SP.MA.NE.ZS          3      -0.90             0.29
# 63847  2004           NE.EXP.GNFS.KD         57       0.44             0.00
# 8476   1965           SH.MED.SAOP.P5          0        NaN              NaN
# 43811  1990           NY.GDP.FCST.KD         39       0.40             0.01
# 57691  2000        FX.OWN.TOTL.PL.ZS          0        NaN              NaN
# 65722  2005           DC.DAC.NZLL.CD         20      -0.19             0.42
# 58058  2000  SL.EMP.1524.SP.MA.NE.ZS         40       0.36             0.02
# 83514  2017        SP.POP.TECH.RD.P6         34       0.59             0.00
# 28718  1979        SP.POP.TECH.RD.P6          0        NaN              NaN
# 73669  2011        TM.TAX.TCOM.BR.ZS         56      -0.44             0.00
#
#         Coefficient  P_value  R_Squared  R_Squared_Adj
# 19118 -2.000000e-01     0.29       0.80           0.61
# 63847  4.673216e+09     0.00       0.19           0.18
# 8476            NaN      NaN        NaN            NaN
# 43811  2.694528e+10     0.01       0.16           0.14
# 57691           NaN      NaN        NaN            NaN
# 65722 -4.902256e+04     0.42       0.04          -0.02
# 58058  2.300000e-01     0.02       0.13           0.11
# 83514  2.241000e+01     0.00       0.34           0.32
# 28718           NaN      NaN        NaN            NaN
# 73669 -5.800000e-01     0.00       0.19           0.18

# %%
df_results.sort_values("Pearson R")
# Out:
#        Year            Indicator Code  Countries  Pearson R  Pearson P-value  \
# 63604  2004         SL.SRV.0714.MA.ZS          3       -1.0             0.05
# 15592  1970               FR.INR.RINR          4       -1.0             0.00
# 77886  2014  per_lm_alllm.adq_pop_tot          3       -1.0             0.05
# 18476  1972               FR.INR.RINR          4       -1.0             0.00
# 77852  2013               SP.DYN.WFRT          3       -1.0             0.04
# ...     ...                       ...        ...        ...              ...
# 89397  2021            SG.VAW.GOES.ZS          0        NaN              NaN
# 89398  2021            SG.VAW.NEGL.ZS          0        NaN              NaN
# 89399  2021            SG.VAW.REFU.ZS          0        NaN              NaN
# 89400  2021         SP.M15.2024.FE.ZS          0        NaN              NaN
# 89401  2021         SP.M18.2024.FE.ZS          0        NaN              NaN
#
#        Coefficient  P_value  R_Squared  R_Squared_Adj
# 63604        -1.36     0.05       0.99           0.99
# 15592        -0.12     0.00       0.99           0.99
# 77886        -1.23     0.05       0.99           0.99
# 18476        -0.12     0.00       0.99           0.99
# 77852        -0.05     0.04       1.00           0.99
# ...            ...      ...        ...            ...
# 89397          NaN      NaN        NaN            NaN
# 89398          NaN      NaN        NaN            NaN
# 89399          NaN      NaN        NaN            NaN
# 89400          NaN      NaN        NaN            NaN
# 89401          NaN      NaN        NaN            NaN
#
# [89404 rows x 9 columns]

# %% [markdown]
# ### 3.3 Add Topic to the Dataframe

# %%
df_series = pd.read_csv("../data/WDISeries.csv")

print(df_series.shape)

df_series.sample(5)
# Out:
# (1442, 21)
#                Series Code                                             Topic  \
# 22          AG.LND.TRAC.ZS              Environment: Agricultural production
# 1266     SP.POP.0004.MA.5Y                     Health: Population: Structure
# 1130  SL.EMP.TOTL.SP.MA.ZS      Social Protection & Labor: Economic activity
# 1183     SL.TLF.ACTI.MA.ZS  Social Protection & Labor: Labor force structure
# 1021     SH.STA.OWGH.ME.ZS                                 Health: Nutrition
#
#                                          Indicator Name Short definition  \
# 22    Agricultural machinery, tractors per 100 sq. k...              NaN
# 1266  Population ages 00-04, male (% of male populat...              NaN
# 1130  Employment to population ratio, 15+, male (%) ...              NaN
# 1183  Labor force participation rate, male (% of mal...              NaN
# 1021  Prevalence of overweight (modeled estimate, % ...              NaN
#
#                                         Long definition Unit of measure  \
# 22    Agricultural machinery refers to the number of...             NaN
# 1266  Male population between the ages 0 to 4 as a p...             NaN
# 1130  Employment to population ratio is the proporti...             NaN
# 1183  Labor force participation rate is the proporti...             NaN
# 1021  Prevalence of overweight children is the perce...             NaN
#
#      Periodicity Base Period Other notes Aggregation method  ...  \
# 22        Annual         NaN         NaN   Weighted average  ...
# 1266      Annual         NaN         NaN                NaN  ...
# 1130      Annual         NaN         NaN   Weighted average  ...
# 1183      Annual         NaN         NaN   Weighted average  ...
# 1021      Annual         NaN         NaN   Weighted average  ...
#
#                              Notes from original source  \
# 22                                                  NaN
# 1266                                                NaN
# 1130  Given the exceptional situation, including the...
# 1183  Given the exceptional situation, including the...
# 1021                                                NaN
#
#                                        General comments  \
# 22                                                  NaN
# 1266                                                NaN
# 1130  National estimates are also available in the W...
# 1183  National estimates are also available in the W...
# 1021  Once considered only a high-income economy pro...
#
#                                                  Source  \
# 22    Food and Agriculture Organization, electronic ...
# 1266  United Nations Population Division. World Popu...
# 1130  International Labour Organization. “ILO Modell...
# 1183  International Labour Organization. “ILO modell...
# 1021  UNICEF, WHO, World Bank: Joint child malnutrit...
#
#                     Statistical concept and methodology  \
# 22    A tractor provides the power and traction to m...
# 1266                                                NaN
# 1130  The employment-to-population ratio indicates h...
# 1183  The labor force is the supply of labor availab...
# 1021                                                NaN
#
#                                   Development relevance Related source links  \
# 22    Agricultural land covers more than one-third o...                  NaN
# 1266                                                NaN                  NaN
# 1130  Four targets were added to the UN Millennium D...                  NaN
# 1183  Estimates of women in the labor force and empl...                  NaN
# 1021                                                NaN                  NaN
#
#      Other web links  Related indicators License Type Unnamed: 20
# 22               NaN                 NaN    CC BY-4.0         NaN
# 1266             NaN                 NaN    CC BY-4.0         NaN
# 1130             NaN                 NaN    CC BY-4.0         NaN
# 1183             NaN                 NaN    CC BY-4.0         NaN
# 1021             NaN                 NaN    CC BY-4.0         NaN
#
# [5 rows x 21 columns]

# %%
df_series.rename(columns={"Series Code":"Indicator Code"}, inplace=True)

df_series.head(1).T
# Out:
#                                                                                      0
# Indicator Code                                                          AG.AGR.TRAC.NO
# Topic                                             Environment: Agricultural production
# Indicator Name                                        Agricultural machinery, tractors
# Short definition                                                                   NaN
# Long definition                      Agricultural machinery refers to the number of...
# Unit of measure                                                                    NaN
# Periodicity                                                                     Annual
# Base Period                                                                        NaN
# Other notes                                                                        NaN
# Aggregation method                                                                 Sum
# Limitations and exceptions           The data are collected by the Food and Agricul...
# Notes from original source                                                         NaN
# General comments                                                                   NaN
# Source                               Food and Agriculture Organization, electronic ...
# Statistical concept and methodology  A tractor provides the power and traction to m...
# Development relevance                Agricultural land covers more than one-third o...
# Related source links                                                               NaN
# Other web links                                                                    NaN
# Related indicators                                                                 NaN
# License Type                                                                 CC BY-4.0
# Unnamed: 20                                                                        NaN

# %%
df_merge = pd.merge(df_results, df_series[["Indicator Code", "Indicator Name", "Topic"]], how="left", on="Indicator Code")

print(df_merge.shape)

df_merge.sample(5)
# Out:
# (89404, 11)
#        Year     Indicator Code  Countries  Pearson R  Pearson P-value  \
# 31382  1981     SH.STA.OWGH.ZS          0        NaN              NaN
# 24289  1976     SE.SEC.PRIV.ZS          0        NaN              NaN
# 29632  1980     SP.DYN.IMRT.IN         55      -0.57             0.00
# 64511  2004  BX.PEF.TOTL.CD.WD         56       0.23             0.09
# 18489  1972  GC.REV.XGRT.GD.ZS         26       0.58             0.00
#
#         Coefficient  P_value  R_Squared  R_Squared_Adj  \
# 31382           NaN      NaN        NaN            NaN
# 24289           NaN      NaN        NaN            NaN
# 29632 -7.800000e-01     0.00       0.33           0.32
# 64511  2.426857e+08     0.09       0.05           0.04
# 18489  1.600000e-01     0.00       0.34           0.31
#
#                                           Indicator Name  \
# 31382  Prevalence of overweight, weight for height (%...
# 24289  School enrollment, secondary, private (% of to...
# 29632     Mortality rate, infant (per 1,000 live births)
# 64511   Portfolio equity, net inflows (BoP, current US$)
# 18489               Revenue, excluding grants (% of GDP)
#
#                                                    Topic
# 31382                                  Health: Nutrition
# 24289                           Education: Participation
# 29632                                  Health: Mortality
# 64511  Economic Policy & Debt: Balance of payments: C...
# 18489         Public Sector: Government finance: Revenue

# %% [markdown]
# #### 3.4 Save the Dataframe to a File

# %%
df_merge.sort_values("Pearson R").to_csv("../data/results.csv", index=False)
